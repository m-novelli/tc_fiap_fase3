# %% [markdown]
# # Conexão com o data lake s3

# %%
import s3fs
import pandas as pd
import pyarrow.parquet as pq
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.dates as mdates
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
Leitura dos dados localmente

df_total = pd.read_csv('C:/Users/mahno/Git/tc_fiap_fase3/datas/dados_base.csv')

 Ajustar os tipos de colunas
df_total['Date'] = pd.to_datetime(df_total['Date'])
df_total['Close'] = df_total['Close'].astype(float)
df_total['High'] = df_total['High'].astype(float)
df_total['Low'] = df_total['Low'].astype(float)
df_total['Open'] = df_total['Open'].astype(float)
df_total['Volume'] = df_total['Volume'].astype(int)
df_total['ticker'] = df_total['ticker'].astype(str)

# %%
#bucket_name = 'fiap-tch3-mlet'
#prefix = 'dados_financeiros/'

# %%
# Inicializa o sistema de arquivos S3
#fs = s3fs.S3FileSystem()

# Lista todos os arquivos Parquet dentro do prefixo
#arquivos = fs.glob(f'{bucket_name}/{prefix}**/dados.parquet')
#print(f"Arquivos encontrados: {len(arquivos)}")
# Out:
# Arquivos encontrados: 133

# %%
# Agora, carrega todos os arquivos e junta
#dfs = []

#for arquivo in arquivos:
#    print(f"Lendo {arquivo}...")

    # Abrir o arquivo
#    with fs.open(arquivo) as f:
#        table = pq.read_table(f)
#        df_temp = table.to_pandas()  # Sem types_mapper aqui

    # Agora, converte a coluna 'ticker' para string
#    if 'ticker' in df_temp.columns:
#        df_temp['ticker'] = df_temp['ticker'].astype(str)

 #   dfs.append(df_temp)
# Out:
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=AAPL/year=2007/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=AAPL/year=2008/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=AAPL/year=2009/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=AAPL/year=2010/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=AAPL/year=2011/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=AAPL/year=2012/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=AAPL/year=2013/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=AAPL/year=2014/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=AAPL/year=2015/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=AAPL/year=2016/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=AAPL/year=2017/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=AAPL/year=2018/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=AAPL/year=2019/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=AAPL/year=2020/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=AAPL/year=2021/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=AAPL/year=2022/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=AAPL/year=2023/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=AAPL/year=2024/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=AAPL/year=2025/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=AMZN/year=2007/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=AMZN/year=2008/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=AMZN/year=2009/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=AMZN/year=2010/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=AMZN/year=2011/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=AMZN/year=2012/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=AMZN/year=2013/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=AMZN/year=2014/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=AMZN/year=2015/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=AMZN/year=2016/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=AMZN/year=2017/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=AMZN/year=2018/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=AMZN/year=2019/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=AMZN/year=2020/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=AMZN/year=2021/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=AMZN/year=2022/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=AMZN/year=2023/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=AMZN/year=2024/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=AMZN/year=2025/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=GOOG/year=2007/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=GOOG/year=2008/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=GOOG/year=2009/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=GOOG/year=2010/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=GOOG/year=2011/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=GOOG/year=2012/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=GOOG/year=2013/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=GOOG/year=2014/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=GOOG/year=2015/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=GOOG/year=2016/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=GOOG/year=2017/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=GOOG/year=2018/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=GOOG/year=2019/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=GOOG/year=2020/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=GOOG/year=2021/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=GOOG/year=2022/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=GOOG/year=2023/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=GOOG/year=2024/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=GOOG/year=2025/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=IBM/year=2007/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=IBM/year=2008/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=IBM/year=2009/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=IBM/year=2010/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=IBM/year=2011/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=IBM/year=2012/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=IBM/year=2013/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=IBM/year=2014/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=IBM/year=2015/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=IBM/year=2016/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=IBM/year=2017/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=IBM/year=2018/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=IBM/year=2019/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=IBM/year=2020/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=IBM/year=2021/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=IBM/year=2022/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=IBM/year=2023/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=IBM/year=2024/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=IBM/year=2025/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=MSFT/year=2007/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=MSFT/year=2008/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=MSFT/year=2009/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=MSFT/year=2010/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=MSFT/year=2011/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=MSFT/year=2012/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=MSFT/year=2013/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=MSFT/year=2014/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=MSFT/year=2015/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=MSFT/year=2016/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=MSFT/year=2017/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=MSFT/year=2018/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=MSFT/year=2019/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=MSFT/year=2020/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=MSFT/year=2021/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=MSFT/year=2022/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=MSFT/year=2023/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=MSFT/year=2024/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=MSFT/year=2025/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=NFLX/year=2007/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=NFLX/year=2008/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=NFLX/year=2009/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=NFLX/year=2010/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=NFLX/year=2011/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=NFLX/year=2012/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=NFLX/year=2013/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=NFLX/year=2014/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=NFLX/year=2015/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=NFLX/year=2016/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=NFLX/year=2017/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=NFLX/year=2018/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=NFLX/year=2019/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=NFLX/year=2020/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=NFLX/year=2021/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=NFLX/year=2022/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=NFLX/year=2023/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=NFLX/year=2024/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=NFLX/year=2025/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=^GSPC/year=2007/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=^GSPC/year=2008/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=^GSPC/year=2009/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=^GSPC/year=2010/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=^GSPC/year=2011/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=^GSPC/year=2012/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=^GSPC/year=2013/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=^GSPC/year=2014/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=^GSPC/year=2015/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=^GSPC/year=2016/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=^GSPC/year=2017/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=^GSPC/year=2018/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=^GSPC/year=2019/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=^GSPC/year=2020/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=^GSPC/year=2021/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=^GSPC/year=2022/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=^GSPC/year=2023/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=^GSPC/year=2024/dados.parquet...
# Lendo fiap-tch3-mlet/dados_financeiros/ticker=^GSPC/year=2025/dados.parquet...

# %%
#df_total = pd.concat(dfs, ignore_index=True)
#print(df_total.head())
# Out:
#         Date     Close      High       Low      Open      Volume ticker
# 0 2007-01-03  2.521843  2.605503  2.464665  2.596776  1238319600   AAPL
# 1 2007-01-04  2.577819  2.586546  2.522446  2.529368   847260400   AAPL
# 2 2007-01-05  2.559461  2.594068  2.539900  2.581128   834741600   AAPL
# 3 2007-01-08  2.572100  2.604000  2.566382  2.586846   797106800   AAPL
# 4 2007-01-09  2.785763  2.798101  2.562469  2.601591  3349298400   AAPL

# %% [markdown]
# ## Análise Exploratória

# %%
#Checando os tipos de dados
print(df_total.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32305 entries, 0 to 32304
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    32305 non-null  datetime64[ns]
#  1   Close   32305 non-null  float64
#  2   High    32305 non-null  float64
#  3   Low     32305 non-null  float64
#  4   Open    32305 non-null  float64
#  5   Volume  32305 non-null  int64
#  6   ticker  32305 non-null  object
# dtypes: datetime64[ns](1), float64(4), int64(1), object(1)
# memory usage: 1.7+ MB
# None

# %%
#Estatísticas descritivas
print(df_total.describe())
# Out:
#                                 Date         Close          High  \
# count                          32305  32305.000000  32305.000000
# mean   2016-03-02 06:06:19.111592704    449.337706    452.316474
# min              2007-01-03 00:00:00      1.751500      1.853500
# 25%              2011-08-01 00:00:00     21.811575     21.997785
# 50%              2016-03-03 00:00:00     88.528542     89.428574
# 75%              2020-10-01 00:00:00    199.479996    201.949997
# max              2025-05-06 00:00:00   6144.149902   6147.430176
# std                              NaN   1000.558505   1005.817496
#
#                 Low          Open        Volume
# count  32305.000000  32305.000000  3.230500e+04
# mean     446.002167    449.237926  6.637197e+08
# min        1.734000      1.764500  1.584340e+05
# 25%       21.615793     21.784778  1.578200e+07
# 50%       87.487813     88.528519  5.013310e+07
# 75%      196.768155    199.490005  1.677012e+08
# max     6111.149902   6134.500000  1.145623e+10
# std      994.548645   1000.389435  1.464494e+09

# %%
#Análise por ticker
tickers = df_total['ticker'].unique()
tickers = [ticker for ticker in tickers if ticker != 'NFLX']
tickers_painel = tickers[:6]

# Criando um painel de gráficos para os tickers de interesse
fig, axs = plt.subplots(2, 3, figsize=(18, 10))  # 2 linhas, 3 colunas
axs = axs.flatten()



for i, ticker in enumerate(tickers_painel):
    df_ticker = df_total[df_total['ticker'] == ticker]
    
    axs[i].plot(df_ticker['Date'], df_ticker['Close'], label=f'{ticker}')
    
    axs[i].set_title(f'{ticker}', fontsize=14)
    axs[i].set_xlabel('Ano')
    axs[i].set_ylabel('Preço de Fechamento')
    
    # Formatar eixo de data
    axs[i].xaxis.set_major_locator(mdates.YearLocator(base=2))  # marca de 2 em 2 anos
    axs[i].xaxis.set_major_formatter(mdates.DateFormatter('%Y'))

    axs[i].grid(alpha=0.3)

    fig.suptitle('Evolução Histórica dos Preços de fechamento dos Tickers de Tecnologia', fontsize=18, y=1.02)

plt.tight_layout()
plt.show()

# %% [markdown]
# Engenharia de Features para séries temporais financeiras

# %% [markdown]
# Carregamento e filtro dos dados
# Selecionar apenas um ticker para análise (ex: AAPL) e garantir que os dados estejam ordenados corretamente no tempo.

# %%
# Filtrar apenas o ticker AAPL
df_aapl = df_total[df_total['ticker'] == 'AAPL'].copy()

# Garantir que a coluna de data está em datetime
df_aapl['Date'] = pd.to_datetime(df_aapl['Date'])

# Ordenar por data e definir como índice
df_aapl = df_aapl.sort_values('Date').set_index('Date')

# %% [markdown]
# Cálculo dos retornos
#
# Calcular o retorno percentual diário, que representa a variação de um dia para o outro.
#
# O retorno percentual é mais informativo que o preço absoluto. É uma métrica padronizada que permite comparar ativos diferentes.

# %%
df_aapl['retorno_1d'] = df_aapl['Close'].pct_change()

# %% [markdown]
# Criação de lags (defasagens)
#
# Incluir como features o preço de fechamento de dias anteriores — ajuda o modelo a aprender padrões temporais.
#
# Modelos como Random Forest ou XGBoost não têm “memória” como redes neurais. Lags ajudam a suprir essa limitação.

# %%
df_aapl['lag_1'] = df_aapl['Close'].shift(1)
df_aapl['lag_2'] = df_aapl['Close'].shift(2)
df_aapl['lag_5'] = df_aapl['Close'].shift(5)

# %% [markdown]
# Médias móveis
#
# Calcular médias dos preços em janelas de tempo (ex: 7 e 14 dias), útil para suavizar variações e capturar tendências.

# %%
df_aapl['sma_7'] = df_aapl['Close'].rolling(window=7).mean()
df_aapl['sma_14'] = df_aapl['Close'].rolling(window=14).mean()

# %% [markdown]
# Volatilidade
#
# Medir a volatilidade de curto prazo, com base no desvio padrão dos retornos diários.
#
# A volatilidade é uma medida de risco. Alta volatilidade pode indicar maior imprevisibilidade.

# %%
df_aapl['volatilidade_7'] = df_aapl['retorno_1d'].rolling(window=7).std()

# %% [markdown]
# RSI (Índice de Força Relativa)
#
# Incluir o RSI, um indicador técnico que mostra se um ativo está “sobrecomprado” ou “sobrevendido”.
#
# RSI varia entre 0 e 100. Valores acima de 70 indicam sobrecompra, abaixo de 30 indicam sobrevenda.

# %%
delta = df_aapl['Close'].diff()
ganhos = np.where(delta > 0, delta, 0)
perdas = np.where(delta < 0, -delta, 0)

media_ganhos = pd.Series(ganhos, index=df_aapl.index).rolling(window=14).mean()
media_perdas = pd.Series(perdas, index=df_aapl.index).rolling(window=14).mean()

rs = media_ganhos / (media_perdas + 1e-10)
df_aapl['rsi_14'] = 100 - (100 / (1 + rs))

# %% [markdown]
# Criação da variável target
#
# Gerar a variável que queremos prever — neste caso, o preço de fechamento do próximo dia.
#
# O modelo vai aprender a prever o valor de Close no dia seguinte com base nas variáveis atuais.

# %%
df_aapl['target'] = df_aapl['Close'].shift(-1)

# %%
df_aapl.head()
df_modelo = df_aapl.dropna().copy()

# %%
df_modelo.head()
# Out:
#                Close      High       Low      Open      Volume ticker  \
# Date
# 2007-01-23  2.579021  2.633491  2.573304  2.579925  1207424400   AAPL
# 2007-01-24  2.609116  2.622658  2.590458  2.608514   927813600   AAPL
# 2007-01-25  2.595573  2.663283  2.588952  2.621453   905973600   AAPL
# 2007-01-26  2.569391  2.629278  2.557655  2.621453   986874000   AAPL
# 2007-01-29  2.586244  2.607610  2.573905  2.597077   901664400   AAPL
#
#             retorno_1d     lag_1     lag_2     lag_5     sma_7    sma_14  \
# Date
# 2007-01-23   -0.012559  2.611823  2.663283  2.922088  2.737356  2.712895
# 2007-01-24    0.011669  2.579021  2.611823  2.857387  2.703308  2.719129
# 2007-01-25   -0.005191  2.609116  2.579021  2.680436  2.656663  2.720397
# 2007-01-26   -0.010087  2.595573  2.609116  2.663283  2.615521  2.721106
# 2007-01-29    0.006559  2.569391  2.595573  2.611823  2.602065  2.722116
#
#             volatilidade_7     rsi_14    target
# Date
# 2007-01-23        0.025999  53.096508  2.609116
# 2007-01-24        0.027991  54.577099  2.595573
# 2007-01-25        0.022885  50.974479  2.569391
# 2007-01-26        0.022848  50.540447  2.586244
# 2007-01-29        0.010813  50.766189  2.574507

# %% [markdown]
# ## Modelagem
#
# Separação treino/teste (base temporal)
#
# Modelo 1 – ARIMA (modelo univariado de série temporal)
#
# Modelo 2 – Random Forest (modelo supervisionado com múltiplas features)
#
# Modelo 3 – XGBoost (modelo gradient boosting com múltiplas features)
#
# Avaliação e comparação de desempenho

# %% [markdown]
# ### ARIMA

# %%
import statsmodels.api as sm
from sklearn.metrics import mean_squared_error
import numpy as np

# Usamos apenas a coluna Close para ARIMA
serie_close = df_modelo['Close']

# Separação temporal (80% treino, 20% teste)
n_total = len(serie_close)
n_treino = int(n_total * 0.8)

treino_arima = serie_close.iloc[:n_treino]
teste_arima = serie_close.iloc[n_treino:]

# Ajuste do modelo ARIMA
# Parâmetros p,d,q escolhidos manualmente para exemplo (p=5, d=1, q=0)
modelo_arima = sm.tsa.ARIMA(treino_arima, order=(5, 1, 0))
modelo_ajustado = modelo_arima.fit()

# Previsão para o período de teste
previsoes_arima = modelo_ajustado.forecast(steps=len(teste_arima))

# Cálculo do RMSE
rmse_arima = np.sqrt(mean_squared_error(teste_arima, previsoes_arima))

# dataframe com resultados
df_result_arima = teste_arima.to_frame(name="Real")
df_result_arima["Previsto_ARIMA"] = previsoes_arima.values

print(df_result_arima.head())
print(f"RMSE (ARIMA): {rmse_arima:.4f}")
# Out:
# c:\Users\mahno\Git\tc_fiap_fase3\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\mahno\Git\tc_fiap_fase3\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\mahno\Git\tc_fiap_fase3\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#                   Real  Previsto_ARIMA
# Date
# 2021-09-02  150.787613      149.468151
# 2021-09-03  151.425430      149.580558
# 2021-09-07  153.770920      149.600072
# 2021-09-08  152.220352      149.592990
# 2021-09-09  151.199753      149.598884
# RMSE (ARIMA): 43.0543
# c:\Users\mahno\Git\tc_fiap_fase3\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# c:\Users\mahno\Git\tc_fiap_fase3\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(

# %%
#Grafico com resultados do modelo

plt.figure(figsize=(12, 6))
plt.plot(teste_arima.index, teste_arima, label="Real", linewidth=2)
plt.plot(teste_arima.index, previsoes_arima, label="Previsto (ARIMA)", linestyle="--")
plt.title("ARIMA – Preço de Fechamento: Real vs Previsto")
plt.xlabel("Data")
plt.ylabel("Preço de Fechamento (USD)")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
print("Início da série prevista:", df_result_arima.index[0])
print("Início da série real:", serie_close.index[0])
# Out:
# Início da série prevista: 2021-09-02 00:00:00
# Início da série real: 2007-01-23 00:00:00

# %% [markdown]
# ## Considerações Modelo ARIMA
#
# O ARIMA é um modelo estatístico clássico para séries temporais. Ele busca capturar padrões passados para prever valores futuros com base apenas nos valores históricos da variável que está sendo modelada.
#
# ARIMA = AutoRegressive Integrated Moving Average, que se traduz como:
#
# AR (p): parte autorregressiva — usa valores passados (Close[t-1], Close[t-2]...).
#
# I (d): diferença — quantas vezes subtrai o valor anterior para tornar a série estacionária.
#
# MA (q): média móvel — modela o erro como combinação de erros anteriores.
#
# Apesar do ARIMA ser um modelo clássico para séries temporais, ele se mostrou incapaz de capturar a complexidade e volatilidade dos preços de ações de tecnologia. A previsão ficou estacionária, mesmo diante de variações significativas. Isso reforça a necessidade de modelos mais sofisticados, como Random Forest ou XGBoost, que permitem o uso de múltiplas variáveis explicativas
#
#
# Estamos usando forecast recursivo, e isso tende a propagar erro, ou seja, estamos prevendo os 20% de dados do teste de uma vez.
#
# Também estamos usando parâmetros fixos para p (autoregressor()), d (diferenciação) e q (média móvel) sem tuning.
#
# Como melhoraria a performance?
# - Tuning dos parametros (autoarima)
# - Teste de Modelos Sazonais (sarima)
# - Uso de variáveis exógenas (arimax)
# - Realimentação do Modelo sempre prevendo apenas um dia a frente, porém computacionalmente mais caro

# %% [markdown]
# ### Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
# Features preditoras
features = ['lag_1', 'lag_2', 'lag_5', 'sma_7', 'sma_14', 'volatilidade_7', 'rsi_14']
X = df_modelo[features]

# Target (preço de fechamento do dia seguinte)
y = df_modelo['target']

# %%
#Divisão treino/teste
n_total = len(df_modelo)
n_treino = int(n_total * 0.8)

X_train = X.iloc[:n_treino]
X_test = X.iloc[n_treino:]
y_train = y.iloc[:n_treino]
y_test = y.iloc[n_treino:]

# %%
#Treinamento do Modelo


modelo_rf = RandomForestRegressor(n_estimators=100, random_state=42)
modelo_rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
#Previsão e Avaliação
y_pred = modelo_rf.predict(X_test)
rmse_rf = np.sqrt(mean_squared_error(y_test, y_pred))
print(f"RMSE (Random Forest): {rmse_rf:.4f}")
# Out:
# RMSE (Random Forest): 43.0619

# %%
plt.figure(figsize=(12, 6))
plt.plot(y_test.index, y_test, label="Real", linewidth=2)
plt.plot(y_test.index, y_pred, label="Previsto (RF)", linestyle="--")
plt.title("Random Forest – Preço de Fechamento: Real vs Previsto")
plt.xlabel("Data")
plt.ylabel("Preço de Fechamento (USD)")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# Nos primeiros dias da janela de teste, o modelo teve acesso a um histórico mais recente e representativo da realidade do mercado.
#
# O modelo aprendeu com padrões vistos no final da janela de treino.
#
# Os dados recentes ainda tinham semelhança estatística com o que foi visto no treino.
#
# Resultado: as primeiras previsões são melhores.
#
# A partir de certo ponto no tempo, o comportamento do ativo muda (ex: rally de alta ou queda forte).
#
# O modelo não foi treinado com dados que representem bem essa nova realidade.
#
# Como o Random Forest não tem "memória", ele regride para a média das previsões mais seguras (desalinhamento temporal)

# %% [markdown]
# Embora o Random Forest seja robusto e útil para problemas tabulares, sua aplicação direta à previsão de preços financeiros apresenta limitações importantes. Neste caso, o modelo tendeu a prever valores médios e não conseguiu capturar a complexidade do comportamento do ativo. Isso sugere a necessidade de refinar o conjunto de variáveis preditoras, considerar a previsão de retornos em vez de preços absolutos ou, ainda, adotar modelos com maior capacidade sequencial.

# %%
importancia = modelo_rf.feature_importances_
for f, i in zip(features, importancia):
    print(f"{f}: {i:.4f}")
# Out:
# lag_1: 0.7647
# lag_2: 0.1113
# lag_5: 0.0015
# sma_7: 0.0755
# sma_14: 0.0466
# volatilidade_7: 0.0002
# rsi_14: 0.0003

# %% [markdown]
# ### XGBoost

# %%
import xgboost as xgb
from sklearn.metrics import mean_squared_error
from math import sqrt

features = ['lag_1', 'lag_2', 'lag_5', 'sma_7', 'sma_14', 'volatilidade_7', 'rsi_14']
target = 'target'

# %%
#Separaçao das variáveis
X = df_modelo[features]
y = df_modelo['target']

# %%
#Separação entre treino e teste

n_total = len(df_modelo)
n_treino = int(n_total * 0.8)

X_train = X.iloc[:n_treino]
X_test = X.iloc[n_treino:]
y_train = y.iloc[:n_treino]
y_test = y.iloc[n_treino:]

# %%
# Treinamento do modelo
modelo_xgb = xgb.XGBRegressor(n_estimators=100, learning_rate=0.1, random_state=42)
modelo_xgb.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.1, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=100,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
#Previsão e avaliação
y_pred_xgb = modelo_xgb.predict(X_test)
rmse_xgb = sqrt(mean_squared_error(y_test, y_pred_xgb))
print(f"RMSE (XGBoost): {rmse_xgb:.4f}")
# Out:
# RMSE (XGBoost): 46.6423

# %%
#Gráfico Real x Previsto

plt.figure(figsize=(12, 6))
plt.plot(y_test.index, y_test, label="Real", linewidth=2)
plt.plot(y_test.index, y_pred_xgb, label="Previsto (XGBoost)", linestyle="--")
plt.title("XGBoost – Preço de Fechamento: Real vs Previsto")
plt.xlabel("Data")
plt.ylabel("Preço de Fechamento (USD)")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# Embora o XGBoost ofereça vantagens em relação a modelos tradicionais, seu desempenho neste estudo mostrou-se limitado ao tentar prever diretamente o valor absoluto do preço de fechamento do dia seguinte. A curva de previsão, embora mais responsiva que Random Forest, ainda não capturou tendências relevantes do ativo. Isso indica que, para esse tipo de tarefa, pode ser mais apropriado modelar a variação percentual (retorno) ou realizar uma classificação binária (subirá ou cairá), ao invés de prever diretamente o preço.

# %% [markdown]
# ### Modelo de previsão de Retorno

# %% [markdown]
# O retorno diário é uma métrica padronizada (percentual) — permite comparação entre diferentes ativos.
#
# O preço absoluto é afetado por escala, por isso difícil de prever com precisão.
#
# Em finanças, o que importa é quanto o ativo valorizou ou desvalorizou, e não apenas o valor nominal

# %%
#Nova definição da variável target
from sklearn.metrics import mean_squared_error, r2_score
from math import sqrt
df_modelo['retorno_target'] = df_modelo['Close'].pct_change().shift(-1)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
from math import sqrt
import xgboost as xgb
import matplotlib.pyplot as plt

# =============================
# 1. Criar variável de retorno a ser prevista
# =============================
df_modelo['retorno_target'] = df_modelo['Close'].pct_change().shift(-1)
df_modelo_ret = df_modelo.dropna(subset=features + ['retorno_target'])

# =============================
# 2. Separar X e y
# =============================
X = df_modelo_ret[features]
y = df_modelo_ret['retorno_target']

# =============================
# 3. Padronizar as features
# =============================
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Recriar os DataFrames com índices preservados
X_scaled = pd.DataFrame(X_scaled, columns=features, index=X.index)

# =============================
# 4. Dividir em treino e teste temporal (80/20)
# =============================
n = len(X_scaled)
n_treino = int(n * 0.8)

X_train = X_scaled.iloc[:n_treino]
X_test = X_scaled.iloc[n_treino:]
y_train = y.iloc[:n_treino]
y_test = y.iloc[n_treino:]

# =============================
# 5. Treinar o modelo XGBoost
# =============================
modelo_xgb = xgb.XGBRegressor(n_estimators=100, learning_rate=0.1, random_state=42)
modelo_xgb.fit(X_train, y_train)

# =============================
# 6. Previsão e avaliação
# =============================
y_pred = modelo_xgb.predict(X_test)
rmse_ret = sqrt(mean_squared_error(y_test, y_pred))
r2_ret = r2_score(y_test, y_pred)

print(f"RMSE (retorno): {rmse_ret:.5f}")
print(f"R² (retorno): {r2_ret:.5f}")

# =============================
# 7. Visualização
# =============================
plt.figure(figsize=(12, 5))
plt.plot(y_test.index, y_test, label="Retorno Real", linewidth=1.5)
plt.plot(y_test.index, y_pred, label="Retorno Previsto", linestyle='--')
plt.title("XGBoost com Normalização – Retorno Diário: Real vs Previsto")
plt.xlabel("Data")
plt.ylabel("Retorno percentual")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# RMSE (retorno): 0.01937
# R² (retorno): -0.11426

# %% [markdown]
# #### Classíficação Binária (retorno dos proximos 5 dias positivo (1) ou negativo (0))

# %% [markdown]
# Filtrar os dados para 2023–2024
#
# Criar a variável retorno_target e o target_binario
#
# Incluir o retorno_gspc como feature
#
# Aplicar engenharia de features (lags, RSI, etc.)
#
# Treinar um XGBClassifier
#
# Avaliar com métricas de classificação: acurácia, precisão, recall, matriz de confusão

# %%
# =============================
# 1. Criar nova variável alvo: retorno acumulado dos próximos 5 dias
# =============================
df_base['retorno_5d'] = df_base['Close'].pct_change(periods=5).shift(-5)
df_base['target_binario_5d'] = (df_base['retorno_5d'] > 0).astype(int)

# =============================
# 2. Remontar o df_modelo com essa nova target
# =============================
features = ['lag_1', 'lag_2', 'lag_5', 'sma_7', 'sma_14', 'volatilidade_7', 'rsi_14', 'retorno_gspc']
df_modelo = df_base.dropna(subset=features + ['target_binario_5d'])

X = df_modelo[features]
y = df_modelo['target_binario_5d']

# =============================
# 3. Normalização das features
# =============================
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_scaled = pd.DataFrame(X_scaled, columns=features, index=X.index)

# =============================
# 4. Separar treino/teste temporalmente (80/20)
# =============================
n = len(X_scaled)
n_treino = int(n * 0.8)
X_train = X_scaled.iloc[:n_treino]
X_test = X_scaled.iloc[n_treino:]
y_train = y.iloc[:n_treino]
y_test = y.iloc[n_treino:]

# =============================
# 5. Treinar o modelo
# =============================
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

clf = XGBClassifier(use_label_encoder=False, eval_metric='logloss', random_state=42)
clf.fit(X_train, y_train)

# =============================
# 6. Avaliação
# =============================
y_pred = clf.predict(X_test)

print("\n📊 Classification Report (5d target):")
print(classification_report(y_test, y_pred))

print("📉 Matriz de confusão:")
print(confusion_matrix(y_test, y_pred))

print("🎯 Acurácia:", accuracy_score(y_test, y_pred))
# Out:
# 📊 Classification Report (5d target):
#               precision    recall  f1-score   support
#
#            0       0.48      0.54      0.51        59
#            1       0.45      0.39      0.42        56
#
#     accuracy                           0.47       115
#    macro avg       0.47      0.47      0.47       115
# weighted avg       0.47      0.47      0.47       115
#
# 📉 Matriz de confusão:
# [[32 27]
#  [34 22]]
# 🎯 Acurácia: 0.46956521739130436
# c:\Users\mahno\Git\tc_fiap_fase3\.venv\Lib\site-packages\xgboost\training.py:183: UserWarning: [21:14:48] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
